# %% [markdown]
# Estructuras de datos python

# %%
#conjunto
a={"arbitraje","conciliacion","transaccion","amigable componedor"}
print(a)
#Tupla
b=("1","3","5","7","9")
print(b)
# Lista
c=["Derecho penal","civil","comercial","famlia","procesal"]
print(c)
# Diccionario (dict)
Glosario_derecho= {"Contrato": "acuerdo legal",
                   "Demanda": "peticion judicial",
                   "ley": "Norma obligatoria"}
print(Glosario_derecho)
# Out:
# {'amigable componedor', 'conciliacion', 'arbitraje', 'transaccion'}
# ('1', '3', '5', '7', '9')
# ['Derecho penal', 'civil', 'comercial', 'famlia', 'procesal']
# {'Contrato': 'acuerdo legal', 'Demanda': 'peticion judicial', 'ley': 'Norma obligatoria'}
