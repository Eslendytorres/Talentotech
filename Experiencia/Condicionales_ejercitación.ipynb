# %%
# Datos iniciales
capacidad_banera = 500  # litros
ritmo_llenado = 200     # litros/hora
volumen_persona = 120   # litros
altura_banera = 80      # cm
altura_sifon = 70       # cm

# Calcular volumen después de 2 horas
tiempo = 2  # horas
agua_ingresada = ritmo_llenado * tiempo

# Verificar si se puede ingresar sin desbordar
puede_ingresar = (agua_ingresada + volumen_persona) <= capacidad_banera

print(f"¿Puede ingresar después de 2 horas?: {puede_ingresar}")

# Considerando el sifón
# Asumimos que la relación altura-volumen es lineal
altura_agua = (agua_ingresada / capacidad_banera) * altura_banera
altura_con_persona = ((agua_ingresada + volumen_persona) / capacidad_banera) * altura_banera

# Verificar si el agua rebasa el sifón
rebasa_sifon = altura_con_persona > altura_sifon

print(f"¿El agua rebasa el sifón al ingresar?: {rebasa_sifon}")
# Out:
# ¿Puede ingresar después de 2 horas?: False
# ¿El agua rebasa el sifón al ingresar?: True

# %% [markdown]
# ¿Qué me pide el problema?
# Determinar si después de 2 horas de llenado puedo ingresar a la bañera sin que se desborde,
# Evaluar el efecto del sifón de desagüe
#
# ¿Qué datos necesito?
# Capacidad de la bañera,
# Ritmo de llenado,
# Volumen que ocupa la persona,
# Alturas de la bañera y el sifón
#
# ¿Cómo debo responder?
# Con comparaciones y colculos matematicos,
# Mostrando resultados

# %%
# Rebajas de invierno
precio_final_invierno = 34  # €
descuento_invierno = 15     # %

# Calcular precio original
precio_original = precio_final_invierno / (1 - descuento_invierno/100)
print(f"Precio original de los pantalones: {precio_original:.2f}€")

# Rebajas de verano
precio_final_verano = 30    # €
descuento_verano = 5        # %

# Calcular precio original en verano (para comparar)
precio_original_verano = precio_final_verano / (1 - descuento_verano/100)

# Comparar qué rebaja es mejor (menor precio final)
invierno_mejor = precio_final_invierno < precio_final_verano

print(f"¿Es mejor comprar en invierno que en verano?: {invierno_mejor}")
# Out:
# Precio original de los pantalones: 40.00€
# ¿Es mejor comprar en invierno que en verano?: False

# %% [markdown]
# ¿Qué me pide el problema?
# Calcular el precio original de los pantalones,
# Comparacion de temporada con el mejor precio ofrecido
#
# ¿Qué datos necesito?
# Precio original,
# Precios con descuento,
# Porcentajes de descuento
#
# ¿Cómo debo responder?
# Calculo de precios originales,
# Comparación precios finales,
# Retornando verdadero/Falso para indicar qué opción es mejor
