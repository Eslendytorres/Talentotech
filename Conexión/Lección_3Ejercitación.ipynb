# %%
import math

class Circulo:
    def __init__(self, radio):
        if radio <= 0:
            raise ValueError("El radio debe ser positivo")
        self.radio = radio

    def area(self):
        return round(math.pi * self.radio ** 2, 2)

    def perimetro(self):
        return round(2 * math.pi * self.radio, 2)

mi_circulo = Circulo(5)
print("Área:", mi_circulo.area())
print("Perímetro:", mi_circulo.perimetro())
# Out:
# Área: 78.54
# Perímetro: 31.42

# %%
class Rectangulo:
    def __init__(self, base, altura):
        if base <= 0 or altura <= 0:
            raise ValueError("Base y altura deben ser positivas")
        self.base = base
        self.altura = altura

    def area(self):
        return self.base * self.altura

mi_rectangulo = Rectangulo(4, 6)
print("Área del rectángulo:", mi_rectangulo.area())
# Out:
# Área del rectángulo: 24

# %%
class StringManipulator:
    def __init__(self):
        self.cadena = ""

    def get_string(self):
        self.cadena = input("Ingrese una cadena: ")

    def print_string(self):
        print(self.cadena.upper())

manipulador = StringManipulator()
manipulador.get_string()
manipulador.print_string()
# Out:
# Ingrese una cadena: Hola mundo
# HOLA MUNDO

# %%
class EnteroARomano:
    def __init__(self):
        self.valores = [
            (1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'),
            (100, 'C'), (90, 'XC'), (50, 'L'), (40, 'XL'),
            (10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')
        ]

    def convertir(self, num):
        if not isinstance(num, int) or num <= 0 or num >= 4000:
            raise ValueError("El número debe ser un entero entre 1 y 3999")

        romano = ''
        for valor, simbolo in self.valores:
            while num >= valor:
                romano += simbolo
                num -= valor
        return romano

conversor = EnteroARomano()
print(conversor.convertir(2023))
print(conversor.convertir(49))
# Out:
# MMXXIII
# XLIX

# %%
class RomanoAEntero:
    def __init__(self):
        self.valores = {
            'I': 1, 'V': 5, 'X': 10, 'L': 50,
            'C': 100, 'D': 500, 'M': 1000
        }

    def convertir(self, romano):
        if not isinstance(romano, str) or not romano:
            raise ValueError("Debe ingresar una cadena no vacía")

        total = 0
        prev_valor = 0

        for simbolo in reversed(romano.upper()):
            valor = self.valores.get(simbolo, None)
            if valor is None:
                raise ValueError(f"Símbolo inválido: {simbolo}")

            if valor < prev_valor:
                total -= valor
            else:
                total += valor
            prev_valor = valor

        return total

conversor = RomanoAEntero()
print(conversor.convertir("MMXXIII"))
print(conversor.convertir("XLIX"))
# Out:
# 2023
# 49
